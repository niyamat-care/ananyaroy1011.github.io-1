# %% [markdown]
# <a href="https://colab.research.google.com/github/arun2424/nlp/blob/main/running_bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/monologg/R-BERT
# Out:
# fatal: destination path 'R-BERT' already exists and is not an empty directory.

# %%
# !pwd
# Out:
# /content

# %%
cd R-BERT
# Out:
# /content/R-BERT

# %%
ls
# Out:
# data/           LICENSE   official_eval.py  requirements.txt    utils.py
# data_loader.py  main.py   predict.py        sample_pred_in.txt
# eval/           model.py  README.md         trainer.py

# %%
pip install -r requirements.txt
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/5d/5e/35140615fc1f925023f489e71086a9ecc188053d263d3594237281284d82/torch-1.6.0-cp37-cp37m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/19/22/aff234f4a841f8999e68a7a94bdd4b60b4cebcfeca5d67d61cd08c9179de/transformers-3.3.1-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/ac/aa/1437691b0c7c83086ebb79ce2da16e00bef024f24fec2a5161c35476f499/sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/75/26/c02ba92ecb8b780bdae4a862d351433c2912fe49469dac7f87a5c85ccca6/tokenizers-0.8.1rc2-cp37-cp37m-manylinux1_x86_64.whl
# ...
# ERROR: torchvision 0.10.0+cu102 has requirement torch==1.9.0, but you'll have torch 1.6.0 which is incompatible.
# ...

# %%
# !python main.py --do_train --do_eval
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  39% 193/500 [03:44<05:56,  1.16s/it]
# Iteration:  39% 194/500 [03:45<05:55,  1.16s/it]
# Iteration:  39% 195/500 [03:46<05:54,  1.16s/it]
# Iteration:  39% 196/500 [03:47<05:53,  1.16s/it]
# Iteration:  39% 197/500 [03:48<05:52,  1.16s/it]
# Iteration:  40% 198/500 [03:50<05:51,  1.16s/it]
# Iteration:  40% 199/500 [03:51<05:50,  1.16s/it]
# Iteration:  40% 200/500 [03:52<05:48,  1.16s/it]
# Iteration:  40% 201/500 [03:53<05:47,  1.16s/it]
# Iteration:  40% 202/500 [03:54<05:45,  1.16s/it]
# Iteration:  41% 203/500 [03:55<05:44,  1.16s/it]
# Iteration:  41% 204/500 [03:56<05:43,  1.16s/it]
# Iteration:  41% 205/500 [03:58<05:42,  1.16s/it]
# Iteration:  41% 206/500 [03:59<05:41,  1.16s/it]
# Iteration:  41% 207/500 [04:00<05:39,  1.16s/it]
# Iteration:  42% 208/500 [04:01<05:38,  1.16s/it]
# Iteration:  42% 209/500 [04:02<05:37,  1.16s/it]
# Iteration:  42% 210/500 [04:03<05:36,  1.16s/it]
# ...

# %%
# !python official_eval.py
# Out:
# macro-averaged F1 = 87.67%

# %%
! python predict.py
# Out:
# 2021-07-02 13:35:45.874478: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 07/02/2021 13:35:54 - INFO - __main__ -   ***** Model Loaded *****
# 07/02/2021 13:35:54 - INFO - __main__ -   Namespace(adam_epsilon=1e-08, add_sep_token=False, data_dir='./data', do_eval=True, do_train=True, dropout_rate=0.1, eval_batch_size=32, eval_dir='./eval', gradient_accumulation_steps=1, label_file='label.txt', learning_rate=2e-05, logging_steps=250, max_grad_norm=1.0, max_seq_len=384, max_steps=-1, model_dir='./model', model_name_or_path='bert-base-uncased', no_cuda=False, num_train_epochs=10.0, save_steps=250, seed=77, task='semeval', test_file='test.tsv', train_batch_size=16, train_file='train.tsv', warmup_steps=0, weight_decay=0.0)
# Predicting: 100% 1/1 [00:00<00:00,  6.84it/s]
# 07/02/2021 13:35:54 - INFO - __main__ -   Prediction Done!
